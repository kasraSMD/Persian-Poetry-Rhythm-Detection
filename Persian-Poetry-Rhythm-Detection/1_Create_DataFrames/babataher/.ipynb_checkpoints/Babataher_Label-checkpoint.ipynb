# %%
import pandas as pd

# %%
babataher = pd.read_csv("babataher.csv", encoding='utf-8')

# %%
babataher
# Out:
#      poem_id  count              title  \
# 0          1      1    دوبیتی شمارهٔ ۱
# 1          2      2    دوبیتی شمارهٔ ۲
# 2          3      3    دوبیتی شمارهٔ ۳
# 3          4      4    دوبیتی شمارهٔ ۴
# 4          5      5    دوبیتی شمارهٔ ۵
# ..       ...    ...                ...
# 363      364    364  دوبیتی شمارهٔ ۳۶۴
# 364      365    365  دوبیتی شمارهٔ ۳۶۵
# 365      366    366  دوبیتی شمارهٔ ۳۶۶
# 366      367      1   باباطاهر - قصیده
# 367      368      1     باباطاهر - غزل
#
# ...

# %%
babataher.isna().sum()
# Out:
# poem_id         0
# count           0
# title           0
# verses          0
# verse_number    0
# label           0
# poet            0
# dtype: int64

# %%
babataher.dtypes
# Out:
# poem_id          int64
# count            int64
# title           object
# verses          object
# verse_number     int64
# label           object
# poet            object
# dtype: object

# %%
pd.set_option('display.max_colwidth', None)

# %%
len(babataher['verses'])
# Out:
# 368

# %%
verse = babataher['verses'][1]

# %%
verse
# Out:
# 'تن محنت کشی دیرم خدایا / دل با غم خوشی دیرم خدایا\nزشوق مسکن و داد غریبی / به سینه آتشی دیرم خدایا\n'

# %%
print(verse)
# Out:
# تن محنت کشی دیرم خدایا / دل با غم خوشی دیرم خدایا
# زشوق مسکن و داد غریبی / به سینه آتشی دیرم خدایا
