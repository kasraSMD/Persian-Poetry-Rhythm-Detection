# %%
import pandas as pd

# %%
saadi = pd.read_csv("saadi.csv", encoding='utf-8')

# %%
saadi
# Out:
#       poem_id  book_name  count  \
# 0           1     بوستان      1
# 1           2     بوستان      2
# 2           3     بوستان      3
# 3           4     بوستان      4
# 4           5     بوستان      5
# ...       ...        ...    ...
# 1806     1807  رسائل نثر      2
# 1807     1808  رسائل نثر      3
# 1808     1809  رسائل نثر      4
# 1809     1810  رسائل نثر      5
# 1810     1811  رسائل نثر      6
#
#                                                   title  \
# 0     بوستان - باب اول در عدل و تدبیر و رای\nبخش ۱ -...
# 1     بوستان - باب اول در عدل و تدبیر و رای\nبخش ۲ -...
# 2     بوستان - باب اول در عدل و تدبیر و رای\nبخش ۳ -...
# 3     بوستان - باب اول در عدل و تدبیر و رای\nبخش ۴ -...
# 4     بوستان - باب اول در عدل و تدبیر و رای\nبخش ۵ -...
# ...                                                 ...
# 1806   رسائل نثر\nشمارهٔ ۲ - رسالهٔ نصیحة الملوک [۱-۷۵]
# 1807  رسائل نثر\nشمارهٔ ۳ - رسالهٔ نصیحة الملوک [۷۶-...
# 1808           رسائل نثر\nشمارهٔ ۴ - رساله در عقل و عشق
# ...

# %%
saadi.isna().sum()
# Out:
# poem_id           0
# book_name         0
# count             0
# title             0
# verses            0
# verse_number      0
# label           553
# poet              0
# dtype: int64

# %%
saadi.dtypes
# Out:
# poem_id          int64
# book_name       object
# count            int64
# title           object
# verses          object
# verse_number     int64
# label           object
# poet            object
# dtype: object

# %%
saadi.dtypes
# Out:
# poem_id          int64
# book_name       object
# count            int64
# title           object
# verses          object
# verse_number     int64
# label           object
# poet            object
# dtype: object

# %%
pd.set_option('display.max_colwidth', None)

# %%
saadi.dtypes
# Out:
# poem_id          int64
# book_name       object
# count            int64
# title           object
# verses          object
# verse_number     int64
# label           object
# poet            object
# dtype: object

# %%
len(saadi['verses'])
# Out:
# 1811

# %%
verse = saadi['verses'][1]

# %%
verse
# Out:
# 'ز دریای عمان برآمد کسی / سفر کرده هامون و دریا بسی\nعرب دیده و ترک و تاجیک و روم / ز هر جنس در نفس پاکش علوم\nجهان گشته و دانش اندوخته / سفر کرده و صحبت آموخته\nبه هیکل قوی چون تناور درخت / ولیکن فرو مانده بی برگ سخت\nدو صد رقعه بالای هم دوخته / ز حراق و او در میان سوخته\nبه شهری در آمد ز دریا کنار / بزرگی در آن ناحیت شهریار\nکه طبعی نکونامی اندیش داشت / سر عجز در پای درویش داشت\nبشستند خدمتگزاران شاه / سر و تن به حمامش از گرد راه\nچو بر آستان ملک سر نهاد / نیایش کنان دست بر بر نهاد\nدرآمد به ایوان شاهنشهی / که بختت جوان باد و دولت رهی\nنرفتم در این مملکت منزلی / کز آسیب آزرده دیدم دلی\nندیدم کسی سرگران از شراب / مگر هم خرابات دیدم خراب\nملک را همین ملک پیرایه بس / که راضی نگرد به آزار کس\nسخن گفت و دامان گوهر فشاند / به نطقی که شه آستین برفشاند\nپسند آمدش حسن گفتار مرد / به نزد خودش خواند و اکرام کرد\nزرش داد و گوهر به شکر قدوم / بپرسیدش از گوهر و زاد و بوم\nبگفت آنچه پرسیدش از سرگذشت / به قربت ز دیگر کسان بر گذشت\nملک با دل خویش با گفت و گو / که دست وزارت سپارد بدو\nولیکن بتدریج ت
# ...

# %%
print(verse)
# Out:
# ز دریای عمان برآمد کسی / سفر کرده هامون و دریا بسی
# عرب دیده و ترک و تاجیک و روم / ز هر جنس در نفس پاکش علوم
# جهان گشته و دانش اندوخته / سفر کرده و صحبت آموخته
# به هیکل قوی چون تناور درخت / ولیکن فرو مانده بی برگ سخت
# دو صد رقعه بالای هم دوخته / ز حراق و او در میان سوخته
# به شهری در آمد ز دریا کنار / بزرگی در آن ناحیت شهریار
# که طبعی نکونامی اندیش داشت / سر عجز در پای درویش داشت
# بشستند خدمتگزاران شاه / سر و تن به حمامش از گرد راه
# چو بر آستان ملک سر نهاد / نیایش کنان دست بر بر نهاد
# درآمد به ایوان شاهنشهی / که بختت جوان باد و دولت رهی
# نرفتم در این مملکت منزلی / کز آسیب آزرده دیدم دلی
# ندیدم کسی سرگران از شراب / مگر هم خرابات دیدم خراب
# ملک را همین ملک پیرایه بس / که راضی نگرد به آزار کس
# سخن گفت و دامان گوهر فشاند / به نطقی که شه آستین برفشاند
# پسند آمدش حسن گفتار مرد / به نزد خودش خواند و اکرام کرد
# زرش داد و گوهر به شکر قدوم / بپرسیدش از گوهر و زاد و بوم
# بگفت آنچه پرسیدش از سرگذشت / به قربت ز دیگر کسان بر گذشت
# ...
