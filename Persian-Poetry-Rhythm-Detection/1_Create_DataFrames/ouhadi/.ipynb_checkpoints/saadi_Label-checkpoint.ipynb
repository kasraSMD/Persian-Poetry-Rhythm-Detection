# %%
import pandas as pd

# %%
saeb = pd.read_csv("saeb.csv", encoding='utf-8')

# %%
saeb
# Out:
#       poem_id  count                                              title  \
# 0           1      1  شمارهٔ ۱ - در وصف کعبه و تخلص به مدح امیرالمؤم...
# 1           2      2  شمارهٔ ۲ - در تعمیر تربت پاک امیرالمؤمنین علی ...
# 2           3      3                      شمارهٔ ۳ - در مدح حضرت رضا(ع)
# 3           4      4                      شمارهٔ ۴ - در مدح حضرت رضا(ع)
# 4           5      5                          شمارهٔ ۵ - در مدح شاه صفی
# ...       ...    ...                                                ...
# 3044     3045   1538                                 تک‌بیت شمارهٔ ۱۵۳۸
# 3045     3046   1539                                 تک‌بیت شمارهٔ ۱۵۳۹
# 3046     3047   1540                                 تک‌بیت شمارهٔ ۱۵۴۰
# 3047     3048   1541                                 تک‌بیت شمارهٔ ۱۵۴۱
# 3048     3049   1542                                 تک‌بیت شمارهٔ ۱۵۴۲
#
#                                                  verses  verse_number  \
# ...

# %%
saeb.isna().sum()
# Out:
# poem_id         0
# count           0
# title           0
# verses          0
# verse_number    0
# label           0
# poet            0
# dtype: int64

# %%
saeb.dtypes
# Out:
# poem_id          int64
# count            int64
# title           object
# verses          object
# verse_number     int64
# label           object
# poet            object
# dtype: object

# %%
saeb.dtypes
# Out:
# poem_id          int64
# count            int64
# title           object
# verses          object
# verse_number     int64
# label           object
# poet            object
# dtype: object

# %%
pd.set_option('display.max_colwidth', None)

# %%
saeb.dtypes
# Out:
# poem_id          int64
# count            int64
# title           object
# verses          object
# verse_number     int64
# label           object
# poet            object
# dtype: object

# %%
len(saeb['verses'])
# Out:
# 3049

# %%
verse = saeb['verses'][1]

# %%
verse
# Out:
# 'منت خدای را که به توفیق کردگار / از ناف کعبه چشمه زمزم شد آشکار\nچون کاروان حاج، خروشان و کف زنان / آمد به خاکبوس نجف آب خوشگوار\nدریای رحمت ازلی جوش فیض زد / شد نهر سلسبیل ز فردوس آشکار\nنهری به طول کاهکشان در دو ماه و نیم / از آسمان خاک نجف گشت آشکار\nدشتی که بود چون جگر تشنه حسین / داغ بهار خلد شد و رشک لاله زار\nصافی دلان که بود تیمم شعارشان / سجاده ها بر آب فکندند موج وار\nدر وادیی که ریگ روان بود آب او / آب حیات بخش خضر یافت انتشار\nجز زهد خشک، خشکی دیگر بجا نماند / زین آب در سراسر این خاک مشکبار\nتخم امید ریگ روان بخت سبز یافت / چشم سفید در نجف رست از غبار\nلب تشنگان خاک نجف ترزبان شدند / از چشمه سار شکر به توفیق کردگار\nهر پاره سنگ او گهر آبدار شد / هر شاخ خشک او شجری گشت میوه دار\nهر دانه ای که بود نهان در ضمیر خاک / منصوروار رفت به معراج شاخسار\nگردید گل گشاده جبین چون کف علی / برگ از نیام شاخ برآمد چو ذوالفقار\nیعقوب وار روشنی بی زوال یافت / نرگس که داشت چشم رمد دیده اش غبار\nهر شاخ پرشکوفه در او جوی شیر شد / مژگان حور گشت در او هر زبان خار\nگل بر هوا فکند کلاه نشاط را / 
# ...

# %%
print(verse)
# Out:
# منت خدای را که به توفیق کردگار / از ناف کعبه چشمه زمزم شد آشکار
# چون کاروان حاج، خروشان و کف زنان / آمد به خاکبوس نجف آب خوشگوار
# دریای رحمت ازلی جوش فیض زد / شد نهر سلسبیل ز فردوس آشکار
# نهری به طول کاهکشان در دو ماه و نیم / از آسمان خاک نجف گشت آشکار
# دشتی که بود چون جگر تشنه حسین / داغ بهار خلد شد و رشک لاله زار
# صافی دلان که بود تیمم شعارشان / سجاده ها بر آب فکندند موج وار
# در وادیی که ریگ روان بود آب او / آب حیات بخش خضر یافت انتشار
# جز زهد خشک، خشکی دیگر بجا نماند / زین آب در سراسر این خاک مشکبار
# تخم امید ریگ روان بخت سبز یافت / چشم سفید در نجف رست از غبار
# لب تشنگان خاک نجف ترزبان شدند / از چشمه سار شکر به توفیق کردگار
# هر پاره سنگ او گهر آبدار شد / هر شاخ خشک او شجری گشت میوه دار
# هر دانه ای که بود نهان در ضمیر خاک / منصوروار رفت به معراج شاخسار
# گردید گل گشاده جبین چون کف علی / برگ از نیام شاخ برآمد چو ذوالفقار
# یعقوب وار روشنی بی زوال یافت / نرگس که داشت چشم رمد دیده اش غبار
# هر شاخ پرشکوفه در او جوی شیر شد / مژگان حور گشت در او هر زبان خار
# ...
